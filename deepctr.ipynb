# %%
# !pip install tensorflow -i https://pypi.tuna.tsinghua.edu.cn/simple

# %%
# !./kesci_submit -token ***************** -file /home/kesci/work/sub.csv
# Out:
# Kesci Submit Tool 4.0.0
#
# > 已验证Token
# > 提交文件 /home/kesci/work/sub.csv (38.83 KiB), Target Qiniu
# > 已上传 100 %
# > 文件已上传
# > 服务器响应: 200 提交成功，请等待评审完成
# > 提交完成

# %%
from itertools import chain

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import optimizers, layers, losses

import pandas as pd
from sklearn.metrics import log_loss, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# from deepctr.feature_column import  SparseFeat, DenseFeat, get_feature_names, build_input_features, get_linear_logit, DEFAULT_GROUP_NAME, input_from_feature_columns
# from deepctr.feature_column import build_input_features, get_linear_logit, input_from_feature_columns
# from deepctr.layers.core import PredictionLayer, DNN
# from deepctr.layers.interaction import SENETLayer, BilinearInteraction
# from deepctr.layers.utils import concat_func, add_func, combined_dnn_input

from deepctr.feature_column import  SparseFeat, DenseFeat, get_feature_names, build_input_features, get_linear_logit, DEFAULT_GROUP_NAME, input_from_feature_columns
from deepctr.layers.core import PredictionLayer, DNN
from deepctr.layers.interaction import FM
from deepctr.layers.utils import concat_func, add_func, combined_dnn_input

# %%
pre1 = pd.read_csv('/home/kesci/work/test_pre.csv').dropna(axis=0,how='any')
pre1 = pre1['id'].astype(int)
pre2 = pd.read_csv('/home/kesci/work/train_pre.csv').dropna(axis=0,how='any')
pre2 = pre2['id'].astype(int)
pre3 = pre1.append(pre2).values.flatten().tolist()

data_test = pd.read_csv('test_.csv')

now = data_test['ID'].astype(int).values.flatten().tolist()
know_test_id = list(set(now)&set(pre3))
need_test_id = list(set(now).difference(set(pre3)))

pre1_ = pd.read_csv('/home/kesci/work/test_pre.csv')
pre2_ = pd.read_csv('/home/kesci/work/train_pre.csv')
pre3_ = pre1_.append(pre2_)

pre_know_id = pd.DataFrame({'id':know_test_id})
pre_need_id = pd.DataFrame({'ID':need_test_id})

pre_konw = pd.merge(pre_know_id, pre3_, on=['id'],how='left')

test_ = pd.merge(pre_need_id, data_test, on=['ID'],how='left')
test = test_.drop(columns=['ID'])

data_train = pd.read_csv('train_.csv')
train = data_train.drop(columns=['ID','肝炎'])
label = data_train['肝炎']

data = train.append(test)
data.columns = ['Age','Gender','Area','Weight','Height','Body_mass_index',
                'Obesity_waistline','Waist','Highest_blood_pressure','Minimum_blood_pressure',
                'Good_Cholesterol','Bad_Cholesterol','Total_Cholesterol','Blood_lipid_abnormality',
                'PVD','Sports_activities','Education','Unmarried','Revenue','Source_of_care',
                'Poor_vision','Drinking','Hypertension','Family_hypertension','Diabetes',
                'Family_diabetes','Family_hepatitis','Chronic_fatigue','ALF']

test.shape
# Out:
# (908, 29)

# %%
dense_features=['Revenue','Sports_activities','Age','Weight','Height',
                'Body_mass_index','Waist','Highest_blood_pressure',
                'Minimum_blood_pressure','Good_Cholesterol','Bad_Cholesterol',
                'Total_Cholesterol']
sparse_features = list(set(data.columns.tolist()).difference(set(dense_features)))

for feat in sparse_features:
    lbe = LabelEncoder()
    data[feat] = lbe.fit_transform(data[feat])
mms = MinMaxScaler(feature_range=(0, 1))
data[dense_features] = mms.fit_transform(data[dense_features])

# 2.count #unique features for each sparse field,and record dense feature field name

fixlen_feature_columns = [SparseFeat(feat, vocabulary_size=data[feat].nunique(),embedding_dim=4)
                        for i,feat in enumerate(sparse_features)] + [DenseFeat(feat, 1,)
                        for feat in dense_features]

dnn_feature_columns = fixlen_feature_columns
linear_feature_columns = fixlen_feature_columns

feature_names = get_feature_names(linear_feature_columns + dnn_feature_columns)

# 3.generate input deepfm_data for model
# train, test = train_test_split(deepfm_data, test_size=0.2)

deepfm_train = data.head(train.shape[0])
deepfm_test = data.tail(test.shape[0])

deepfm_train = {name:deepfm_train[name] for name in feature_names}
deepfm_test = {name:deepfm_test[name] for name in feature_names}

# %%
def multi_category_focal_loss2(gamma=2., alpha=.25):
    """
    Usage:
     model.compile(loss=[multi_category_focal_loss2(
         alpha=0.35, gamma=2)], metrics=["accuracy"], optimizer=adam)
    """
    epsilon = 1.e-7
    gamma = float(gamma)
    alpha = tf.constant(alpha, dtype=tf.float32)

    def multi_category_focal_loss2_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)

        alpha_t = y_true * alpha + \
            (tf.ones_like(y_true) - y_true) * (1 - alpha)
        y_t = tf.multiply(y_true, y_pred) + tf.multiply(1 - y_true, 1 - y_pred)
        ce = -tf.math.log(y_t)
        weight = tf.pow(tf.subtract(1., y_t), gamma)
        fl = tf.multiply(tf.multiply(weight, ce), alpha_t)
        loss = tf.reduce_mean(fl)
        return loss

    return multi_category_focal_loss2_fixed

# %%
 def M( linear_feature_columns, dnn_feature_columns, fm_group=[DEFAULT_GROUP_NAME], dnn_hidden_units=(128, 128),
        l2_reg_linear=0.00001, l2_reg_embedding=0.00001, l2_reg_dnn=0, seed=1024, dnn_dropout=0,
        dnn_activation='elu', dnn_use_bn=False, task='binary'):
    
    features = build_input_features(linear_feature_columns + dnn_feature_columns)

    inputs_list = list(features.values())

    linear_logit = get_linear_logit(features, linear_feature_columns, seed=seed, prefix='linear',
                                    l2_reg=l2_reg_linear)

    group_embedding_dict, dense_value_list = input_from_feature_columns(features, dnn_feature_columns, l2_reg_embedding,
                                                                        seed, support_group=True)

    fm_logit = add_func([FM()(concat_func(v, axis=1))
                         for k, v in group_embedding_dict.items() if k in fm_group])

    dnn_input = combined_dnn_input(list(chain.from_iterable(
        group_embedding_dict.values())), dense_value_list)

    dnn_output = DNN(dnn_hidden_units, dnn_activation, l2_reg_dnn, dnn_dropout,
                     dnn_use_bn, seed)(dnn_input)


    dnn_logit = tf.keras.layers.Dense(
        1, use_bias=False, activation=None)(dnn_output)

    final_logit = add_func([linear_logit, fm_logit, dnn_logit])
    output = PredictionLayer(task)(final_logit)

    model = Model(inputs=[features], outputs=[output])

    model.compile(optimizer=optimizers.Adam(2.5e-4),
                loss={'prediction_layer':losses.binary_crossentropy},# multi_category_focal_loss2(alpha=0.35, gamma=2)
                metrics=['AUC'])
    return model

# %%
model = M(linear_feature_columns=linear_feature_columns, 
        dnn_feature_columns=dnn_feature_columns, task='binary')
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# PVD (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# Obesity_waistline (InputLayer)  [(None, 1)]          0
# __________________________________________________________________________________________________
# Diabetes (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# Family_diabetes (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# Gender (InputLayer)             [(None, 1)]          0
# __________________________________________________________________________________________________
# Blood_lipid_abnormality (InputL [(None, 1)]          0
# __________________________________________________________________________________________________
# Family_hypertension (InputLayer [(None, 1)]          0
# __________________________________________________________________________________________________
# Drinking (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# Unmarried (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# Chronic_fatigue (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# Area (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# Education (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# Family_hepatitis (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# Source_of_care (InputLayer)     [(None, 1)]          0
# __________________________________________________________________________________________________
# Poor_vision (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# Hypertension (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# ALF (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# Revenue (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# Sports_activities (InputLayer)  [(None, 1)]          0
# __________________________________________________________________________________________________
# Age (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# Weight (InputLayer)             [(None, 1)]          0
# __________________________________________________________________________________________________
# Height (InputLayer)             [(None, 1)]          0
# __________________________________________________________________________________________________
# Body_mass_index (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# Waist (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# Highest_blood_pressure (InputLa [(None, 1)]          0
# __________________________________________________________________________________________________
# Minimum_blood_pressure (InputLa [(None, 1)]          0
# __________________________________________________________________________________________________
# Good_Cholesterol (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# Bad_Cholesterol (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# Total_Cholesterol (InputLayer)  [(None, 1)]          0
# __________________________________________________________________________________________________
# sparse_emb_PVD (Embedding)      (None, 1, 4)         8           PVD[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Obesity_waistline (E (None, 1, 4)         12          Obesity_waistline[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Diabetes (Embedding) (None, 1, 4)         12          Diabetes[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Family_diabetes (Emb (None, 1, 4)         8           Family_diabetes[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Gender (Embedding)   (None, 1, 4)         8           Gender[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Blood_lipid_abnormal (None, 1, 4)         8           Blood_lipid_abnormality[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Family_hypertension  (None, 1, 4)         8           Family_hypertension[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Drinking (Embedding) (None, 1, 4)         8           Drinking[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Unmarried (Embedding (None, 1, 4)         12          Unmarried[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Chronic_fatigue (Emb (None, 1, 4)         12          Chronic_fatigue[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Area (Embedding)     (None, 1, 4)         16          Area[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Education (Embedding (None, 1, 4)         12          Education[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Family_hepatitis (Em (None, 1, 4)         12          Family_hepatitis[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Source_of_care (Embe (None, 1, 4)         20          Source_of_care[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Poor_vision (Embeddi (None, 1, 4)         12          Poor_vision[0][0]
# __________________________________________________________________________________________________
# sparse_emb_Hypertension (Embedd (None, 1, 4)         12          Hypertension[0][0]
# __________________________________________________________________________________________________
# sparse_emb_ALF (Embedding)      (None, 1, 4)         12          ALF[0][0]
# __________________________________________________________________________________________________
# no_mask_4 (NoMask)              (None, 1, 4)         0           sparse_emb_PVD[0][0]
#                                                                  sparse_emb_Obesity_waistline[0][0
#                                                                  sparse_emb_Diabetes[0][0]
#                                                                  sparse_emb_Family_diabetes[0][0]
#                                                                  sparse_emb_Gender[0][0]
#                                                                  sparse_emb_Blood_lipid_abnormalit
#                                                                  sparse_emb_Family_hypertension[0]
#                                                                  sparse_emb_Drinking[0][0]
#                                                                  sparse_emb_Unmarried[0][0]
#                                                                  sparse_emb_Chronic_fatigue[0][0]
#                                                                  sparse_emb_Area[0][0]
#                                                                  sparse_emb_Education[0][0]
#                                                                  sparse_emb_Family_hepatitis[0][0]
#                                                                  sparse_emb_Source_of_care[0][0]
#                                                                  sparse_emb_Poor_vision[0][0]
#                                                                  sparse_emb_Hypertension[0][0]
#                                                                  sparse_emb_ALF[0][0]
# __________________________________________________________________________________________________
# no_mask_5 (NoMask)              (None, 1)            0           Revenue[0][0]
#                                                                  Sports_activities[0][0]
#                                                                  Age[0][0]
#                                                                  Weight[0][0]
#                                                                  Height[0][0]
#                                                                  Body_mass_index[0][0]
#                                                                  Waist[0][0]
#                                                                  Highest_blood_pressure[0][0]
#                                                                  Minimum_blood_pressure[0][0]
#                                                                  Good_Cholesterol[0][0]
#                                                                  Bad_Cholesterol[0][0]
#                                                                  Total_Cholesterol[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 1, 68)        0           no_mask_4[0][0]
#                                                                  no_mask_4[1][0]
#                                                                  no_mask_4[2][0]
#                                                                  no_mask_4[3][0]
#                                                                  no_mask_4[4][0]
#                                                                  no_mask_4[5][0]
#                                                                  no_mask_4[6][0]
#                                                                  no_mask_4[7][0]
#                                                                  no_mask_4[8][0]
#                                                                  no_mask_4[9][0]
#                                                                  no_mask_4[10][0]
#                                                                  no_mask_4[11][0]
#                                                                  no_mask_4[12][0]
#                                                                  no_mask_4[13][0]
#                                                                  no_mask_4[14][0]
#                                                                  no_mask_4[15][0]
#                                                                  no_mask_4[16][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 12)           0           no_mask_5[0][0]
#                                                                  no_mask_5[1][0]
#                                                                  no_mask_5[2][0]
#                                                                  no_mask_5[3][0]
#                                                                  no_mask_5[4][0]
#                                                                  no_mask_5[5][0]
#                                                                  no_mask_5[6][0]
#                                                                  no_mask_5[7][0]
#                                                                  no_mask_5[8][0]
#                                                                  no_mask_5[9][0]
#                                                                  no_mask_5[10][0]
#                                                                  no_mask_5[11][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_PVD (Embeddin (None, 1, 1)         2           PVD[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Obesity_waist (None, 1, 1)         3           Obesity_waistline[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Diabetes (Emb (None, 1, 1)         3           Diabetes[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Family_diabet (None, 1, 1)         2           Family_diabetes[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Gender (Embed (None, 1, 1)         2           Gender[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Blood_lipid_a (None, 1, 1)         2           Blood_lipid_abnormality[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Family_hypert (None, 1, 1)         2           Family_hypertension[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Drinking (Emb (None, 1, 1)         2           Drinking[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Unmarried (Em (None, 1, 1)         3           Unmarried[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Chronic_fatig (None, 1, 1)         3           Chronic_fatigue[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Area (Embeddi (None, 1, 1)         4           Area[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Education (Em (None, 1, 1)         3           Education[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Family_hepati (None, 1, 1)         3           Family_hepatitis[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Source_of_car (None, 1, 1)         5           Source_of_care[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Poor_vision ( (None, 1, 1)         3           Poor_vision[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_Hypertension  (None, 1, 1)         3           Hypertension[0][0]
# __________________________________________________________________________________________________
# linear0sparse_emb_ALF (Embeddin (None, 1, 1)         3           ALF[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 68)           0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 12)           0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# no_mask (NoMask)                (None, 1, 1)         0           linear0sparse_emb_PVD[0][0]
#                                                                  linear0sparse_emb_Obesity_waistli
#                                                                  linear0sparse_emb_Diabetes[0][0]
#                                                                  linear0sparse_emb_Family_diabetes
#                                                                  linear0sparse_emb_Gender[0][0]
#                                                                  linear0sparse_emb_Blood_lipid_abn
#                                                                  linear0sparse_emb_Family_hyperten
#                                                                  linear0sparse_emb_Drinking[0][0]
#                                                                  linear0sparse_emb_Unmarried[0][0]
#                                                                  linear0sparse_emb_Chronic_fatigue
#                                                                  linear0sparse_emb_Area[0][0]
#                                                                  linear0sparse_emb_Education[0][0]
#                                                                  linear0sparse_emb_Family_hepatiti
#                                                                  linear0sparse_emb_Source_of_care[
#                                                                  linear0sparse_emb_Poor_vision[0][
#                                                                  linear0sparse_emb_Hypertension[0]
#                                                                  linear0sparse_emb_ALF[0][0]
# __________________________________________________________________________________________________
# no_mask_1 (NoMask)              (None, 1)            0           Revenue[0][0]
#                                                                  Sports_activities[0][0]
#                                                                  Age[0][0]
#                                                                  Weight[0][0]
#                                                                  Height[0][0]
#                                                                  Body_mass_index[0][0]
#                                                                  Waist[0][0]
#                                                                  Highest_blood_pressure[0][0]
#                                                                  Minimum_blood_pressure[0][0]
#                                                                  Good_Cholesterol[0][0]
#                                                                  Bad_Cholesterol[0][0]
#                                                                  Total_Cholesterol[0][0]
# __________________________________________________________________________________________________
# no_mask_3 (NoMask)              (None, 1, 4)         0           sparse_emb_PVD[0][0]
#                                                                  sparse_emb_Obesity_waistline[0][0
#                                                                  sparse_emb_Diabetes[0][0]
#                                                                  sparse_emb_Family_diabetes[0][0]
#                                                                  sparse_emb_Gender[0][0]
#                                                                  sparse_emb_Blood_lipid_abnormalit
#                                                                  sparse_emb_Family_hypertension[0]
#                                                                  sparse_emb_Drinking[0][0]
#                                                                  sparse_emb_Unmarried[0][0]
#                                                                  sparse_emb_Chronic_fatigue[0][0]
#                                                                  sparse_emb_Area[0][0]
#                                                                  sparse_emb_Education[0][0]
#                                                                  sparse_emb_Family_hepatitis[0][0]
#                                                                  sparse_emb_Source_of_care[0][0]
#                                                                  sparse_emb_Poor_vision[0][0]
#                                                                  sparse_emb_Hypertension[0][0]
#                                                                  sparse_emb_ALF[0][0]
# __________________________________________________________________________________________________
# no_mask_6 (NoMask)              multiple             0           flatten[0][0]
#                                                                  flatten_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1, 17)        0           no_mask[0][0]
#                                                                  no_mask[1][0]
#                                                                  no_mask[2][0]
#                                                                  no_mask[3][0]
#                                                                  no_mask[4][0]
#                                                                  no_mask[5][0]
#                                                                  no_mask[6][0]
#                                                                  no_mask[7][0]
#                                                                  no_mask[8][0]
#                                                                  no_mask[9][0]
#                                                                  no_mask[10][0]
#                                                                  no_mask[11][0]
#                                                                  no_mask[12][0]
#                                                                  no_mask[13][0]
#                                                                  no_mask[14][0]
#                                                                  no_mask[15][0]
#                                                                  no_mask[16][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12)           0           no_mask_1[0][0]
#                                                                  no_mask_1[1][0]
#                                                                  no_mask_1[2][0]
#                                                                  no_mask_1[3][0]
#                                                                  no_mask_1[4][0]
#                                                                  no_mask_1[5][0]
#                                                                  no_mask_1[6][0]
#                                                                  no_mask_1[7][0]
#                                                                  no_mask_1[8][0]
#                                                                  no_mask_1[9][0]
#                                                                  no_mask_1[10][0]
#                                                                  no_mask_1[11][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 17, 4)        0           no_mask_3[0][0]
#                                                                  no_mask_3[1][0]
#                                                                  no_mask_3[2][0]
#                                                                  no_mask_3[3][0]
#                                                                  no_mask_3[4][0]
#                                                                  no_mask_3[5][0]
#                                                                  no_mask_3[6][0]
#                                                                  no_mask_3[7][0]
#                                                                  no_mask_3[8][0]
#                                                                  no_mask_3[9][0]
#                                                                  no_mask_3[10][0]
#                                                                  no_mask_3[11][0]
#                                                                  no_mask_3[12][0]
#                                                                  no_mask_3[13][0]
#                                                                  no_mask_3[14][0]
#                                                                  no_mask_3[15][0]
#                                                                  no_mask_3[16][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 80)           0           no_mask_6[0][0]
#                                                                  no_mask_6[1][0]
# __________________________________________________________________________________________________
# linear (Linear)                 (None, 1)            12          concatenate[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# fm (FM)                         (None, 1)            0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dnn (DNN)                       (None, 128)          26880       concatenate_5[0][0]
# __________________________________________________________________________________________________
# no_mask_2 (NoMask)              (None, 1)            0           linear[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1)            0           fm[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            128         dnn[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1)            0           no_mask_2[0][0]
#                                                                  add[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# prediction_layer (PredictionLay (None, 1)            1           add_1[0][0]
# ==================================================================================================
# Total params: 27,261
# Trainable params: 27,261
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
input_train = deepfm_train
model.fit(input_train,
            {'prediction_layer':label},
            validation_split=0.3,
            epochs=25,
            batch_size=100,)
# Out:
# Epoch 1/25
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# 42/42 [==============================] - 1s 33ms/step - loss: 0.4930 - auc: 0.5972 - val_loss: 0.1929 - val_auc: 0.8099
# Epoch 2/25
# 42/42 [==============================] - 1s 14ms/step - loss: 0.2429 - auc: 0.7601 - val_loss: 0.1662 - val_auc: 0.8179
# Epoch 3/25
# 42/42 [==============================] - 1s 14ms/step - loss: 0.2384 - auc: 0.7941 - val_loss: 0.1648 - val_auc: 0.8378
# Epoch 4/25
# 42/42 [==============================] - 1s 12ms/step - loss: 0.2333 - auc: 0.8122 - val_loss: 0.1598 - val_auc: 0.8517
# Epoch 5/25
# 42/42 [==============================] - 0s 12ms/step - loss: 0.2268 - auc: 0.8275 - val_loss: 0.1535 - val_auc: 0.8652
# Epoch 6/25
# 42/42 [==============================] - 1s 12ms/step - loss: 0.2192 - auc: 0.8410 - val_loss: 0.1479 - val_auc: 0.8732
# Epoch 7/25
# 42/42 [==============================] - 0s 12ms/step - loss: 0.2119 - auc: 0.8487 - val_loss: 0.1396 - val_auc: 0.8771
# Epoch 8/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2060 - auc: 0.8529 - val_loss: 0.1343 - val_auc: 0.8795
# Epoch 9/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.2018 - auc: 0.8560 - val_loss: 0.1315 - val_auc: 0.8814
# Epoch 10/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1988 - auc: 0.8577 - val_loss: 0.1298 - val_auc: 0.8836
# Epoch 11/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1969 - auc: 0.8597 - val_loss: 0.1294 - val_auc: 0.8846
# Epoch 12/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1961 - auc: 0.8610 - val_loss: 0.1267 - val_auc: 0.8846
# Epoch 13/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1954 - auc: 0.8623 - val_loss: 0.1263 - val_auc: 0.8872
# Epoch 14/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1946 - auc: 0.8633 - val_loss: 0.1259 - val_auc: 0.8865
# Epoch 15/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1944 - auc: 0.8630 - val_loss: 0.1263 - val_auc: 0.8866
# Epoch 16/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1946 - auc: 0.8628 - val_loss: 0.1254 - val_auc: 0.8863
# Epoch 17/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1937 - auc: 0.8643 - val_loss: 0.1254 - val_auc: 0.8868
# Epoch 18/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1933 - auc: 0.8646 - val_loss: 0.1254 - val_auc: 0.8891
# Epoch 19/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1935 - auc: 0.8641 - val_loss: 0.1261 - val_auc: 0.8900
# Epoch 20/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1933 - auc: 0.8638 - val_loss: 0.1255 - val_auc: 0.8896
# Epoch 21/25
# 42/42 [==============================] - 0s 12ms/step - loss: 0.1932 - auc: 0.8641 - val_loss: 0.1275 - val_auc: 0.8878
# Epoch 22/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1930 - auc: 0.8647 - val_loss: 0.1254 - val_auc: 0.8891
# Epoch 23/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1925 - auc: 0.8646 - val_loss: 0.1275 - val_auc: 0.8889
# Epoch 24/25
# 42/42 [==============================] - 0s 11ms/step - loss: 0.1930 - auc: 0.8649 - val_loss: 0.1256 - val_auc: 0.8865
# Epoch 25/25
# 42/42 [==============================] - 0s 10ms/step - loss: 0.1927 - auc: 0.8647 - val_loss: 0.1279 - val_auc: 0.8894

# %%
input_test = deepfm_test
ans_mtx = model.predict(input_test,
                        batch_size=100)

# %%
ans_sub = pd.DataFrame({'ID':test_['ID'].astype(int),'hepatitis':ans_mtx.flatten()})

# %%
pre_konw.columns = ['ID','hepatitis']
ans_sub = ans_sub.append(pre_konw)#.drop_duplicates(['ID'])

# %%
ans_sub.to_csv('sub.csv',index=0)

# %%
ans_sub
# Out:
#         ID  hepatitis
# 0     6146   0.004193
# 1     8196   0.003300
# 2     8197   0.008630
# 3     8198   0.047996
# 4     8199   0.110326
# 5     6152   0.040158
# 6     6151   0.005426
# 7     8202   0.009288
# 8     6154   0.001273
# 9     8204   0.008440
# 10    6156   0.002098
# 11    8206   0.014025
# 12    6158   0.122986
# 13    6159   0.006650
# 14    6161   0.003139
# 15    6163   0.030884
# 16    6165   0.010543
# 17    6166   0.031954
# 18    6168   0.006165
# 19    8218   0.010908
# 20    6171   0.009597
# 21    6176   0.126978
# 22    8226   0.024880
# 23    8227   0.038332
# 24    8228   0.028576
# 25    6178   0.025798
# 26    6179   0.007293
# 27    6180   0.048558
# 28    6184   0.005073
# 29    8233   0.161824
# ...    ...        ...
# 1847  5911   0.000000
# 1848  5913   0.000000
# 1849  5915   0.000000
# 1850  5916   1.000000
# 1851  5918   0.000000
# 1852  5925   0.000000
# 1853  5926   0.000000
# 1854  5927   1.000000
# 1855  5929   0.000000
# 1856  5930   0.000000
# 1857  5942   0.000000
# 1858  5944   0.000000
# 1859  5950   0.000000
# 1860  5952   1.000000
# 1861  5956   1.000000
# 1862  5958   0.000000
# 1863  5959   0.000000
# 1864  5962   0.000000
# 1865  5963   0.000000
# 1866  5964   0.000000
# 1867  5965   0.000000
# 1868  5968   0.000000
# 1869  5975   0.000000
# 1870  5979   1.000000
# 1871  5984   0.000000
# 1872  5986   0.000000
# 1873  5987   0.000000
# 1874  5988   0.000000
# 1875  5990   0.000000
# 1876  5993   0.000000
#
# [2785 rows x 2 columns]
